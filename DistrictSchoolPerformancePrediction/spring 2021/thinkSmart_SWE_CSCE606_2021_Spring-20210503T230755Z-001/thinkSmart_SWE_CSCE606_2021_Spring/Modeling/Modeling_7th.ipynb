# %% [markdown]
# Current 7th math

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1d366225-5039-4ef4-b00f-b12faf6893fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d366225-5039-4ef4-b00f-b12faf6893fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving math_7th.csv to math_7th.csv
# Saving reading_7th.csv to reading_7th.csv

# %%
import pandas as pd
math=pd.read_csv('math_7th.csv')

# %%
import pandas as pd
math=pd.get_dummies(math,columns=['Ethnicity'])

# %%
math.head()
# Out:
#    LocalId  Grade  ECD  ...  Ethnicity_B  Ethnicity_H  Ethnicity_W
# 0     3701      7    1  ...            0            1            0
# 1     4054      7    1  ...            0            0            1
# 2     1085      7    1  ...            1            0            0
# 3     9988      7    1  ...            0            1            0
# 4     3201      7    1  ...            1            0            0
#
# [5 rows x 14 columns]

# %%
math_analysis=math.iloc[:,2:]
math_analysis.head()
x_math=math_analysis.drop('Spring 2019 STAAR\nMA05\nPcntScore\n5/2019 or 6/2019',axis=1)
y_math=math_analysis['Spring 2019 STAAR\nMA05\nPcntScore\n5/2019 or 6/2019']
x_math.shape
# Out:
# (45, 11)

# %%
from sklearn.model_selection import train_test_split
X_train_math, X_test_math, y_train_math, y_test_math = train_test_split(x_math, y_math, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train_math, y_train_math)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_values=regressor.predict(X_test_math)
pd.DataFrame({'Actual':y_test_math,'Predicted':pred_values})

pred_values=list(pred_values)
diff=list(abs(pred_values-y_test_math))
cutoff=15
count=0


for i in range(0,len(diff)):
  if (diff[i]<cutoff):
    count=count+1
print(count/len(diff)*100)
# Out:
# 66.66666666666666

# %%
regressor.score(X_test_math,y_test_math)
regressor.coef_
# Out:
# array([ 0.        ,  2.30106931, -2.40165757,  0.08571021, -0.30793672,
#         0.57669455, -0.16182963,  0.81819497, -1.57588979, -6.91840164,
#         8.49429143])

# %%
import pickle
pickle.dump(regressor,open("7th_math",'wb'))

# %% [markdown]
# Cuurent 7th English

# %%
reading=pd.read_csv('reading_7th.csv')
import pandas as pd
reading=pd.get_dummies(reading,columns=['Ethnicity'])

# %%
reading.head()
# Out:
#    LocalId  Grade  ECD  ...  Ethnicity_B  Ethnicity_H  Ethnicity_W
# 0     3701      7    1  ...            0            1            0
# 1     4054      7    1  ...            0            0            1
# 2     1085      7    1  ...            1            0            0
# 3     9988      7    1  ...            0            1            0
# 4     3201      7    1  ...            1            0            0
#
# [5 rows x 14 columns]

# %%
reading_analysis=reading.iloc[:,2:]
reading_analysis.head()
x_reading=reading_analysis.drop('Spring 2019 STAAR\nRE05\nPcntScore 5/2019 or 6/2019',axis=1)
y_reading=reading_analysis['Spring 2019 STAAR\nRE05\nPcntScore 5/2019 or 6/2019']
x_reading.shape
# Out:
# (45, 11)

# %%
from sklearn.model_selection import train_test_split
X_train_reading, X_test_reading, y_train_reading, y_test_reading = train_test_split(x_reading, y_reading, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
regressor1.fit(X_train_reading, y_train_reading)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor1.score(X_test_reading,y_test_reading)
# Out:
# 0.4238409489393396

# %%
pred_values=regressor1.predict(X_test_reading)
pd.DataFrame({'Actual':y_test_reading,'Predicted':pred_values})

pred_values=list(pred_values)
diff=list(abs(pred_values-y_test_reading))
cutoff=15
count=0


for i in range(0,len(diff)):
  if (diff[i]<cutoff):
    count=count+1
print(count/len(diff)*100)
# Out:
# 66.66666666666666

# %%
import pickle
pickle.dump(regressor1,open("7th_reading",'wb'))
