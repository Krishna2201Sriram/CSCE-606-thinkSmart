# %% [markdown]
# 6th Math model

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90d3fff2-c81f-41e3-aa78-96d991f4c9ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90d3fff2-c81f-41e3-aa78-96d991f4c9ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving math_6th.csv to math_6th.csv
# Saving reading_6th.csv to reading_6th.csv

# %%
math=pd.read_csv('math_6th.csv')

# %%
import pandas as pd
math=pd.get_dummies(math,columns=['Ethnicity'])

# %%
math.head()
# Out:
#    LocalId  Grade  ...  Ethnicity_H  Ethnicity_W
# 0     2750      6  ...            1            0
# 1     2842      6  ...            1            0
# 2     2513      6  ...            1            0
# 3     9989      6  ...            0            1
# 4     2545      6  ...            0            0
#
# [5 rows x 14 columns]

# %%
math_analysis=math.iloc[:,2:]
math_analysis.head()
x_math=math_analysis.drop('Spring 2018 STAAR\nMA04\nPcntScore\n5/2019',axis=1)
y_math=math_analysis['Spring 2018 STAAR\nMA04\nPcntScore\n5/2019']
x_math.shape
# Out:
# (43, 11)

# %%
from sklearn.model_selection import train_test_split
X_train_math, X_test_math, y_train_math, y_test_math = train_test_split(x_math, y_math, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train_math, y_train_math)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.score(X_test_math,y_test_math)

pred_values=regressor.predict(X_test_math)
pd.DataFrame({'Actual':y_test_math,'Predicted':pred_values})

pred_values=list(pred_values)
diff=list(abs(pred_values-y_test_math))
cutoff=15
count=0


for i in range(0,len(diff)):
  if (diff[i]<cutoff):
    count=count+1
print(count/len(diff)*100)
regressor.score(X_test_math,y_test_math)
# Out:
# 88.88888888888889
# 0.5743156979329188

# %%
import pickle
final_model= pickle.dump(regressor,open("6th_math",'wb'))

# %%
#Polynomial regression
from sklearn.preprocessing import PolynomialFeatures
pre_process = PolynomialFeatures(degree=2)
X_poly = pre_process.fit_transform(X_train_math)
X_poly[30].shape
poly_reg=LinearRegression()
poly_fit=poly_reg.fit(X_poly,y_train_math)
test_poly=pre_process.fit_transform(X_test_math)
poly_predict=poly_fit.predict(test_poly)
poly_fit.score(test_poly,y_test_math)
# Out:
# -14.164716975253679

# %%
from sklearn.ensemble import RandomForestRegressor
RandomForestRegModel= RandomForestRegressor()
RandomForestRegModel.fit(X_train_math,y_train_math)
pred_randomforest=RandomForestRegModel.predict(X_test_math)
RandomForestRegModel.score(X_test_math,y_test_math)
# Out:
# 0.5492415309901473

# %% [markdown]
# 6th Reading model

# %%
reading=pd.read_csv('reading_6th.csv')
import pandas as pd
reading=pd.get_dummies(reading,columns=['Ethnicity'])

# %%
reading.head()
# Out:
#    LocalId  Grade  ...  Ethnicity_H  Ethnicity_W
# 0     2750      6  ...            1            0
# 1     2842      6  ...            1            0
# 2     2513      6  ...            1            0
# 3     9989      6  ...            0            1
# 4     2545      6  ...            0            0
#
# [5 rows x 14 columns]

# %%
reading_analysis=reading.iloc[:,2:]
reading_analysis.head()
x_reading=reading_analysis.drop('Spring 2018 ELAR Released BM\n2/14/2019',axis=1)
y_reading=reading_analysis['Spring 2018 ELAR Released BM\n2/14/2019']
x_reading.shape
# Out:
# (43, 11)

# %%
from sklearn.model_selection import train_test_split
X_train_reading, X_test_reading, y_train_reading, y_test_reading = train_test_split(x_reading, y_reading, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
regressor1.fit(X_train_reading, y_train_reading)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor1.score(X_test_reading,y_test_reading)
# Out:
# 0.5151518252578197

# %%
regressor.score(X_test_reading,y_test_reading)

pred_values=regressor.predict(X_test_reading)
pd.DataFrame({'Actual':y_test_reading,'Predicted':pred_values})

pred_values=list(pred_values)
diff=list(abs(pred_values-y_test_reading))
cutoff=15
count=0


for i in range(0,len(diff)):
  if (diff[i]<cutoff):
    count=count+1
print(count/len(diff)*100)
# Out:
# 60.0

# %%
#Polynomial regression
from sklearn.preprocessing import PolynomialFeatures
pre_process = PolynomialFeatures(degree=2)
X_poly = pre_process.fit_transform(X_train_reading)
poly_reg=LinearRegression()
poly_fit=poly_reg.fit(X_poly,y_train_reading)
test_poly=pre_process.fit_transform(X_test_reading)
poly_predict=poly_fit.predict(test_poly)
poly_fit.score(test_poly,y_test_reading)
# Out:
# -5.2735814040906615

# %%
from sklearn.ensemble import RandomForestRegressor
RandomForestRegModel= RandomForestRegressor()
RandomForestRegModel.fit(X_train_reading,y_train_reading)
pred_randomforest=RandomForestRegModel.predict(X_test_reading)
RandomForestRegModel.score(X_test_reading,y_test_reading)
# Out:
# 0.29184395620757886

# %%
import pickle
final_model1= pickle.dump(regressor1,open("6th_reading",'wb'))
